# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/Ice_cream selling data.csv")

# %%
df.head()
# Out:
#    Temperature (°C)  Ice Cream Sales (units)
# 0         -4.662263                41.842986
# 1         -4.316559                34.661120
# 2         -4.213985                39.383001
# 3         -3.949661                37.539845
# 4         -3.578554                32.284531

# %%
df.tail()
# Out:
#     Temperature (°C)  Ice Cream Sales (units)
# 44          3.610778                28.912188
# 45          3.704057                17.843957
# 46          4.130868                34.530743
# 47          4.133534                27.698383
# 48          4.899032                41.514822

# %%
df.describe()
# Out:
#        Temperature (°C)  Ice Cream Sales (units)
# count         49.000000                49.000000
# mean           0.271755                15.905308
# std            2.697672                12.264682
# min           -4.662263                 0.328626
# 25%           -2.111870                 4.857988
# 50%            0.688781                12.615181
# 75%            2.784836                25.142082
# max            4.899032                41.842986

# %%
df.isnull().sum()
# Out:
# Temperature (°C)           0
# Ice Cream Sales (units)    0
# dtype: int64

# %%
df.corr()
# Out:
#                          Temperature (°C)  Ice Cream Sales (units)
# Temperature (°C)                 1.000000                -0.175184
# Ice Cream Sales (units)         -0.175184                 1.000000

# %%
sns.scatterplot(x="Temperature (°C)",y="Ice Cream Sales (units)",data=df)
# Out:
# <Axes: xlabel='Temperature (°C)', ylabel='Ice Cream Sales (units)'>

# %%
sns.lineplot(x="Temperature (°C)",y="Ice Cream Sales (units)",data = df)
# Out:
# <Axes: xlabel='Temperature (°C)', ylabel='Ice Cream Sales (units)'>

# %%
sns.histplot(x="Ice Cream Sales (units)",data=df,kde=True)
plt.show()

# %%
x=df.iloc[:,0:1].values

# %%
x
# Out:
# array([[-4.66226268],
#        [-4.31655945],
#        [-4.21398476],
#        [-3.94966109],
#        [-3.57855372],
#        [-3.4557117 ],
#        [-3.10844012],
#        [-3.08130332],
#        [-2.67246083],
#        [-2.65228679],
#        [-2.65149803],
#        [-2.288264  ],
#        [-2.11186969],
#        [-1.81893761],
#        [-1.66034773],
#        [-1.32637898],
#        [-1.17312327],
#        [-0.77333004],
#        [-0.6737528 ],
#        [-0.14963487],
#        [-0.0361565 ],
#        [-0.03389529],
#        [ 0.0086077 ],
#        [ 0.14924457],
#        [ 0.68878091],
#        [ 0.69359887],
#        [ 0.87490503],
#        [ 1.02418081],
#        [ 1.24071162],
#        [ 1.35981267],
#        [ 1.74000001],
#        [ 1.85055193],
#        [ 1.99931037],
#        [ 2.0751006 ],
#        [ 2.31859124],
#        [ 2.471946  ],
#        [ 2.78483646],
#        [ 2.83176021],
#        [ 2.95993209],
#        [ 3.02087431],
#        [ 3.21136614],
#        [ 3.27004407],
#        [ 3.31607252],
#        [ 3.33593241],
#        [ 3.61077848],
#        [ 3.70405744],
#        [ 4.13086796],
#        [ 4.13353379],
#        [ 4.89903151]])

# %%
y =df.iloc[:,1].values
y
# Out:
# array([41.84298632, 34.66111954, 39.38300088, 37.53984488, 32.28453119,
#        30.00113848, 22.63540128, 25.36502221, 19.22697005, 20.27967918,
#        13.2758285 , 18.12399121, 11.21829447, 10.01286785, 12.61518115,
#        10.95773134,  6.68912264,  9.39296866,  5.21016262,  4.67364254,
#         0.32862552,  0.89760319,  3.16560001,  1.93141603,  2.57678224,
#         4.62568946,  0.78997365,  2.31380636,  1.29236081,  0.95311531,
#         3.78257014,  4.8579878 ,  8.94382321,  8.17073494,  7.41209403,
#        10.33663062, 15.99661997, 12.56823739, 21.34291574, 20.11441346,
#        22.8394055 , 16.98327874, 25.14208223, 26.10474041, 28.91218793,
#        17.84395652, 34.53074274, 27.69838335, 41.51482194])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state =0)

# %%
x_train
# Out:
# array([[ 1.02418081],
#        [ 4.89903151],
#        [-4.21398476],
#        [ 4.13086796],
#        [-0.6737528 ],
#        [-1.32637898],
#        [ 1.24071162],
#        [ 0.0086077 ],
#        [-1.17312327],
#        [ 3.27004407],
#        [-0.0361565 ],
#        [ 3.31607252],
#        [-2.67246083],
#        [-1.81893761],
#        [ 0.69359887],
#        [-3.4557117 ],
#        [-0.77333004],
#        [ 2.471946  ],
#        [-1.66034773],
#        [ 2.95993209],
#        [-4.31655945],
#        [-2.11186969],
#        [ 3.33593241],
#        [ 0.68878091],
#        [-3.10844012],
#        [ 0.14924457],
#        [ 2.78483646],
#        [-0.03389529],
#        [-0.14963487],
#        [-2.65228679],
#        [ 3.02087431],
#        [ 3.70405744],
#        [-3.94966109],
#        [-4.66226268],
#        [ 4.13353379],
#        [ 3.61077848]])

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
from sklearn.preprocessing import PolynomialFeatures

from sklearn.pipeline import make_pipeline

# %%
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
y_train
# Out:
# array([ 2.31380636, 41.51482194, 39.38300088, 34.53074274,  5.21016262,
#        10.95773134,  1.29236081,  3.16560001,  6.68912264, 16.98327874,
#         0.32862552, 25.14208223, 19.22697005, 10.01286785,  4.62568946,
#        30.00113848,  9.39296866, 10.33663062, 12.61518115, 21.34291574,
#        34.66111954, 11.21829447, 26.10474041,  2.57678224, 22.63540128,
#         1.93141603, 15.99661997,  0.89760319,  4.67364254, 20.27967918,
#        20.11441346, 17.84395652, 37.53984488, 41.84298632, 27.69838335,
#        28.91218793])

# %%
model.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures()),
#                 ('linearregression', LinearRegression())])

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([ 5.40555876, 44.59467026,  3.99128169,  7.31587194,  9.0229113 ,
#        16.71758613, 11.57489591, 21.34762426, 35.26734727, 28.1761013 ,
#        22.885142  ,  8.00356024,  9.58372668])

# %%
from sklearn import metrics

# %%
score1= metrics.r2_score(y_test,y_pred)

# %%
score1
# Out:
# 0.4941378367564838
